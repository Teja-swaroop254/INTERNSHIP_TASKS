# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
k=int(input())
if k%2!=0:
    print('Weird')
elif k%2==0 and 2<=k and k<=5:
    print('Not Weird') 
elif k%2==0 and 6<=k and k<=20:
    print('Weird') 
elif k>20 and k%2==0:
    print('Not Weird')
# Out:
# 3
# Weird

# %%
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
# Out:
# 3
# 5
# 8
# -2
# 15

# %%
a=int(input())
b=int(input())
print(a//b)
print(a/b)
# Out:
# 3
# 5
# 0
# 0.6

# %%
k=int(input())

for i in range(k):
    print(i*i)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %%
def is_leap(year):
    leap = False
    
    # Write your logic here
    if (year%4==0 and year%100!=0) or (year%400==0):
        leap=True
    
    
        return leap
    else:
        return leap    

year = int(input())
print(is_leap(year))
# Out:
# 1900
# False

# %%
k=int(input())
c=""
for i in range(1,k+1):
    c=c+str(i)
print(c)
# Out:
# 3
# 123
